# %%
# %sql
CREATE TABLE sdp_catalog.sources.sales (

    order_id INT,
    product_id INT,
    revenue FLOAT,
    date DATE,
    store_id INT

);



INSERT INTO sdp_catalog.sources.sales VALUES 
(1, 1001, 100.00, '2022-01-01', 1),
(2, 1002, 200.00, '2022-01-02', 1),
(3, 1003, 300.00, '2022-01-03', 2),
(4, 1004, 400.00, '2022-01-04', 2),
(5, 1005, 500.00, '2022-01-05', 3),
(6, 1006, 600.00, '2022-01-06', 3),
(7, 1007, 700.00, '2022-01-07', 4),
(8, 1008, 800.00, '2022-01-08', 4),
(9, 1009, 900.00, '2022-01-09', 5),
(10, 1010, 1000.00, '2022-01-10', 5);
